# %%
import random
ladder={3:16,9:25,17:38,27:57,42:99,68:88,77:91}
snake={11:1,24:13,44:22,66:33,98:51,79:19}
pos1=0
pos2=0
def move(pos):
    dice=random.randint(1,6)
    print(f"Dice:{dice}")
    pos=pos+dice
    if pos in snake:
        print("Bitten by snake")
        pos=snake[pos]
        print(f"Position:{pos}")
    elif pos in ladder:
        print("Climed by ladder")
        pos=ladder[pos]
        print(f"Position:{pos}")
    else:
        print(f"Position:{pos}")
    print("\n")
    return pos
while True:
        A=input("Player 1 Enter \"A\" to throw dice")
        pos1=move(pos1)
        if pos1>=100:
            print("Game over\n Player 1 wins")
            break
        B=input("Player 2 Enter \"B\" to throw dice")
        pos2=move(pos2)
        if pos2>=100:
            print("Game over\n Player 2 wins")
            break
# Out:
# Player 1 Enter "A" to throw diceA
# Dice:4
# Position:4
#
#
# Player 2 Enter "B" to throw diceB
# Dice:2
# Position:2
#
#
# Player 1 Enter "A" to throw diceA
# Dice:2
# Position:6
#
#
# Player 2 Enter "B" to throw diceB
# Dice:2
# Position:4
#
#
# Player 1 Enter "A" to throw diceA
# Dice:3
# Climed by ladder
# Position:25
#
#
# Player 2 Enter "B" to throw diceB
# Dice:1
# Position:5
#
#
# Player 1 Enter "A" to throw diceA
# Dice:4
# Position:29
#
#
# Player 2 Enter "B" to throw diceB
# Dice:5
# Position:10
#
#
# Player 1 Enter "A" to throw diceA
# Dice:4
# Position:33
#
#
# Player 2 Enter "B" to throw diceB
# Dice:6
# Position:16
#
#
# Player 1 Enter "A" to throw diceA
# Dice:6
# Position:39
#
#
# Player 2 Enter "B" to throw diceB
# Dice:1
# Climed by ladder
# Position:38
#
#
# Player 1 Enter "A" to throw diceA
# Dice:1
# Position:40
#
#
# Player 2 Enter "B" to throw diceB
# Dice:1
# Position:39
#
#
# Player 1 Enter "A" to throw diceA
# Dice:3
# Position:43
#
#
# Player 2 Enter "B" to throw diceB
# Dice:4
# Position:43
#
#
# Player 1 Enter "A" to throw diceA
# Dice:2
# Position:45
#
#
# Player 2 Enter "B" to throw diceB
# Dice:5
# Position:48
#
#
# Player 1 Enter "A" to throw diceA
# Dice:5
# Position:50
#
#
# Player 2 Enter "B" to throw diceB
# Dice:3
# Position:51
#
#
# Player 1 Enter "A" to throw diceA
# Dice:5
# Position:55
#
#
# Player 2 Enter "B" to throw diceB
# Dice:6
# Position:57
#
#
# Player 1 Enter "A" to throw diceA
# Dice:1
# Position:56
#
#
# Player 2 Enter "B" to throw diceB
# Dice:4
# Position:61
#
#
# Player 1 Enter "A" to throw diceA
# Dice:1
# Position:57
#
#
# Player 2 Enter "B" to throw diceB
# Dice:1
# Position:62
#
#
# Player 1 Enter "A" to throw diceA
# Dice:5
# Position:62
#
#
# Player 2 Enter "B" to throw diceB
# Dice:6
# Climed by ladder
# Position:88
#
#
# Player 1 Enter "A" to throw diceA
# Dice:5
# Position:67
#
#
# Player 2 Enter "B" to throw diceB
# Dice:5
# Position:93
#
#
# Player 1 Enter "A" to throw diceA
# Dice:4
# Position:71
#
#
# Player 2 Enter "B" to throw diceB
# Dice:3
# Position:96
#
#
# Player 1 Enter "A" to throw diceA
# Dice:1
# Position:72
#
#
# Player 2 Enter "B" to throw diceB
# Dice:1
# Position:97
#
#
# Player 1 Enter "A" to throw diceA
# Dice:5
# Climed by ladder
# Position:91
#
#
# Player 2 Enter "B" to throw diceB
# Dice:2
# Position:99
#
#
# Player 1 Enter "A" to throw diceA
# Dice:5
# Position:96
#
#
# Player 2 Enter "B" to throw diceB
# Dice:6
# Position:105
#
#
# Game over
#  Player 2 wins
